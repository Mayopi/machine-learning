# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
plt.title('Jill Solar Panel')
plt.xlabel('times (in day)')
plt.ylabel('Generated power (in Kilojoule)')
ax.set_xlim([0, 300])
ax.set_ylim([0, 300])
ax.plot(t, d_1, 'red')
ax.plot(t, d_2, 'green')
plt.axvline(x=75, color='purple', linestyle='--')
_ = plt.axhline(y=225, color='purple', linestyle='--')
